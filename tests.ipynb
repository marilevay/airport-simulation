# %% [markdown]
# # Additional Tests for the Simulation

# %%
from simulation.classes import Airport, Queue, Passenger
from simulation.helpers import run_simulation
import numpy as np
import random

# %% [markdown]
# ## Test 1
# If the passengers are being allocated to the additional service 3% of the time

# %%
queue = Queue(timestamp=0, service_rate=1/2)
additional_service_count = 0
run_until = 10000 # number of samples

for i in range(run_until):
    # create a new passenger for each trial
    passenger = Passenger(id=i, arrival_time=0)
    if passenger.needs_additional_screening:
        additional_service_count += 1
        
proportion = additional_service_count / run_until
print(f"Proportion needing additional screening: {proportion:.2f}")

# Calculate confidence interval
z_score = 1.96  # for 95% confidence
margin_of_error = z_score * np.sqrt(proportion * (1 - proportion) / run_until)
confidence_interval = (proportion - margin_of_error, proportion + margin_of_error)
print(f"95% confidence interval: {confidence_interval}")
# Out:
# Proportion needing additional screening: 0.03
# 95% confidence interval: (0.027792385689430214, 0.03460761431056979)

# %%
# Alternative way to test this
queue_multi, arrivals_multi, completed_passengers = run_simulation(arrival_rate=10, service_rate=1/2, service_distribution=None, additional_screening_distribution=None, run_until=1000, num_queues=3)

# Count passengers who needed additional screening
additional_screening_count = sum(1 for p in completed_passengers.values() if p.needs_additional_screening)

total_passengers = len(completed_passengers)
proportion = additional_screening_count / total_passengers if total_passengers > 0 else 0

print(f"Passengers needing additional screening: {additional_screening_count}/{total_passengers} ({proportion:.1%})")
# Out:
# Passengers needing additional screening: 30/1000 (3.0%)

# %% [markdown]
# ## Test 2
# Check whether passengers are being assigned to the shortest queue

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3]  # 1 passenger
airport.passenger_queues[2].waiting = [passenger4, passenger5, passenger6]  # 3 passengers

# Find shortest queue
shortest_queue = airport.find_shortest_queue()
shortest_index = airport.passenger_queues.index(shortest_queue)
print(f"Shortest queue index: {shortest_index}, with {len(shortest_queue.waiting)} passengers waiting")

# Verify it's actually the shortest
queue_lengths = [q.total_passengers() for q in airport.passenger_queues]
print(f"All queue lengths: {queue_lengths}")
print(f"Test passed: {queue_lengths[shortest_index] == min(queue_lengths)}")
# Out:
# Shortest queue index: 1, with 1 passengers waiting
# All queue lengths: [2, 1, 3]
# Test passed: True

# %% [markdown]
# ## Test 3
# Check if passengers are randomly assigned to a queue when all queues are the same length

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3, passenger4]  # 2 passengers
airport.passenger_queues[2].waiting = [passenger5, passenger6]  # 2 passengers

# Here, we want to test if the proportion of passengers assigned to each queue is roughly equal over many trials
num_trials = 1000
selected_indices = []

for _ in range(num_trials):
    selected_queue = airport.find_shortest_queue()
    selected_index = airport.passenger_queues.index(selected_queue)
    selected_indices.append(selected_index)

# Count how many times each queue was selected
queue_0_count = selected_indices.count(0)
queue_1_count = selected_indices.count(1)
queue_2_count = selected_indices.count(2)

perc_1 = (queue_0_count/num_trials)*100
perc_2 = (queue_1_count/num_trials)*100
perc_3 = (queue_2_count/num_trials)*100

print(f"Queue selection distribution over {num_trials} trials:")
print(f"Queue 0: {queue_0_count} times ({perc_1:.1f}%)")
print(f"Queue 1: {queue_1_count} times ({perc_2:.1f}%)")
print(f"Queue 2: {queue_2_count} times ({perc_3:.1f}%)")
# Out:
# Queue selection distribution over 1000 trials:
# Queue 0: 347 times (34.7%)
# Queue 1: 311 times (31.1%)
# Queue 2: 342 times (34.2%)

# %% [markdown]
# ## Test 4
# Testing queue placing dynamics, meant to check whether:
# * There are unique arrival and departure events for each new passenger
# * When a passenger arrives, they are placed on the shortest queue or assigned at random when all queues have the same length
# * When a passenger leaves, according to the scheduled time, they leave the queue completely

# %%
# Parameters
run_until = 100
num_queues = 3
avg_waiting_times = []
arrival_rate = 10 # minutes
service_rate = 1/2 # minutes

airport = Airport(arrival_rate, service_rate, num_queues)

# Schedule the specified number of arrivals
current_time = 0
for _ in range(run_until):
    airport.add_arrival(current_time)
    current_time = airport.curr_arrival_time  # Use the scheduled arrival time for next scheduling

# Initial schedule before any service
airport.print_schedule() 
    
while airport.priority_q:
    airport.run_next_service()
    airport.print_schedule()
# Out:
# Airport at time (minutes) 0: 100 total waiting, 0 total being served
#   Queue 1: 34 waiting, 0 being served.
#   Queue 2: 33 waiting, 0 being served.
#   Queue 3: 33 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.03: arrival for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 0.15: arrival for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 0.17: arrival for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 0.27: arrival for passenger 4 at queue 1
# 	 Scheduled Timestamp (minutes) 0.3: arrival for passenger 5 at queue 2
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.027: 99 total waiting, 1 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 33 waiting, 0 being served.
#   Queue 3: 33 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.15: arrival for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 0.17: arrival for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 0.27: arrival for passenger 4 at queue 1
# 	 Scheduled Timestamp (minutes) 0.3: arrival for passenger 5 at queue 2
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.64: departure for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.148: 98 total waiting, 2 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 32 waiting, 1 being served.
#   Queue 3: 33 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.17: arrival for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 0.27: arrival for passenger 4 at queue 1
# 	 Scheduled Timestamp (minutes) 0.3: arrival for passenger 5 at queue 2
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.29: departure for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.64: departure for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.17: 97 total waiting, 3 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 32 waiting, 1 being served.
#   Queue 3: 32 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.27: arrival for passenger 4 at queue 1
# 	 Scheduled Timestamp (minutes) 0.3: arrival for passenger 5 at queue 2
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.21: departure for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 3.29: departure for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.64: departure for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.274: 97 total waiting, 3 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 32 waiting, 1 being served.
#   Queue 3: 32 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.3: arrival for passenger 5 at queue 2
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.21: departure for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 3.29: departure for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.64: departure for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.304: 97 total waiting, 3 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 32 waiting, 1 being served.
#   Queue 3: 32 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.45: arrival for passenger 6 at queue 3
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.21: departure for passenger 3 at queue 3
# 	 Scheduled Timestamp (minutes) 3.29: departure for passenger 2 at queue 2
# 	 Scheduled Timestamp (minutes) 3.34: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.41: arrival for passenger 32 at queue 2
# 	 Scheduled Timestamp (minutes) 3.49: arrival for passenger 33 at queue 3
# 	 Scheduled Timestamp (minutes) 3.52: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.55: arrival for passenger 35 at queue 2
# 	 Scheduled Timestamp (minutes) 3.64: departure for passenger 1 at queue 1
# 	 Scheduled Timestamp (minutes) 3.71: arrival for passenger 36 at queue 3
# 	 Scheduled Timestamp (minutes) 3.74: arrival for passenger 37 at queue 2
# 	 Scheduled Timestamp (minutes) 3.82: arrival for passenger 38 at queue 1
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 39 at queue 3
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 40 at queue 2
# 	 Scheduled Timestamp (minutes) 3.99: arrival for passenger 41 at queue 1
# 	 Scheduled Timestamp (minutes) 4.09: arrival for passenger 42 at queue 3
# 	 Scheduled Timestamp (minutes) 4.22: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.25: arrival for passenger 44 at queue 1
# 	 Scheduled Timestamp (minutes) 4.27: arrival for passenger 45 at queue 3
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 46 at queue 1
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 47 at queue 2
# 	 Scheduled Timestamp (minutes) 4.38: arrival for passenger 48 at queue 3
# 	 Scheduled Timestamp (minutes) 4.39: arrival for passenger 49 at queue 3
# 	 Scheduled Timestamp (minutes) 4.48: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.53: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 52 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 5.19: arrival for passenger 53 at queue 1
# 	 Scheduled Timestamp (minutes) 5.27: arrival for passenger 54 at queue 3
# 	 Scheduled Timestamp (minutes) 5.3: arrival for passenger 55 at queue 1
# 	 Scheduled Timestamp (minutes) 5.42: arrival for passenger 56 at queue 2
# 	 Scheduled Timestamp (minutes) 5.44: arrival for passenger 57 at queue 3
# 	 Scheduled Timestamp (minutes) 5.48: arrival for passenger 58 at queue 3
# 	 Scheduled Timestamp (minutes) 5.58: arrival for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.99: arrival for passenger 61 at queue 3
# 	 Scheduled Timestamp (minutes) 6.14: arrival for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 6.31: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 7.11: arrival for passenger 64 at queue 3
# 	 Scheduled Timestamp (minutes) 7.16: arrival for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 7.21: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 7.54: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 7.61: arrival for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 7.67: arrival for passenger 69 at queue 3
# 	 Scheduled Timestamp (minutes) 7.74: arrival for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 7.8: arrival for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 7.94: arrival for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 8.0: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 8.06: arrival for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 8.2: arrival for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 8.21: arrival for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 8.42: arrival for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 8.5: arrival for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 8.87: arrival for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 8.91: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.99: arrival for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 9.22: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 9.27: arrival for passenger 86 at queue 1
# 	 Scheduled Timestamp (minutes) 9.42: arrival for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 9.49: arrival for passenger 88 at queue 2
# 	 [Additional Screening] Scheduled Timestamp (minutes) 9.51: arrival for passenger 89 at queue 1
# 	 Scheduled Timestamp (minutes) 10.04: arrival for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 10.08: arrival for passenger 91 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 10.54: arrival for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 10.97: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.98: arrival for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 11.03: arrival for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 11.23: arrival for passenger 98 at queue 1
# 	 Scheduled Timestamp (minutes) 11.3: arrival for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 11.39: arrival for passenger 100 at queue 1
#
#
# Airport at time (minutes) 0.447: 97 total waiting, 3 total being served
#   Queue 1: 33 waiting, 1 being served.
#   Queue 2: 32 waiting, 1 being served.
#   Queue 3: 32 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 0.56: arrival for passenger 7 at queue 3
# 	 Scheduled Timestamp (minutes) 0.7: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 1.02: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 1.25: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 1.37: arrival for passenger 11 at queue 2
# 	 Scheduled Timestamp (minutes) 1.51: arrival for passenger 12 at queue 3
# 	 Scheduled Timestamp (minutes) 1.55: arrival for passenger 13 at queue 3
# 	 Scheduled Timestamp (minutes) 1.61: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.66: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.74: arrival for passenger 16 at queue 3
# 	 Scheduled Timestamp (minutes) 1.83: arrival for passenger 17 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 18 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 19 at queue 3
# 	 Scheduled Timestamp (minutes) 2.2: arrival for passenger 20 at queue 1
# 	 Scheduled Timestamp (minutes) 2.37: arrival for passenger 21 at queue 2
# 	 Scheduled Timestamp (minutes) 2.49: arrival for passenger 22 at queue 3
# 	 Scheduled Timestamp (minutes) 2.61: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.74: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 25 at queue 3
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 26 at queue 1
# 	 Scheduled Timestamp (minutes) 2.99: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 3.04: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 3.14: arrival for passenger 29 at queue 2
# 	 Scheduled Timestamp (minutes) 3.15: arrival for passenger 30 at queue 3
# 	 Scheduled Timestamp (minutes) 3.21: departure for passenger 3 at queue 3
# ...
# 	 Scheduled Timestamp (minutes) 72.47: departure for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 73.46: departure for passenger 59 at queue 1
#
#
# Airport at time (minutes) 70.108: 33 total waiting, 3 total being served
#   Queue 1: 14 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 9 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 72.47: departure for passenger 68 at queue 2
# 	 Scheduled Timestamp (minutes) 73.15: departure for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 73.46: departure for passenger 59 at queue 1
#
#
# Airport at time (minutes) 72.468: 32 total waiting, 3 total being served
#   Queue 1: 14 waiting, 1 being served.
#   Queue 2: 9 waiting, 1 being served.
#   Queue 3: 9 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 73.15: departure for passenger 72 at queue 3
# 	 Scheduled Timestamp (minutes) 73.46: departure for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 75.61: departure for passenger 71 at queue 2
#
#
# Airport at time (minutes) 73.149: 31 total waiting, 3 total being served
#   Queue 1: 14 waiting, 1 being served.
#   Queue 2: 9 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 73.46: departure for passenger 59 at queue 1
# 	 Scheduled Timestamp (minutes) 75.61: departure for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 76.19: departure for passenger 73 at queue 3
#
#
# Airport at time (minutes) 73.465: 30 total waiting, 3 total being served
#   Queue 1: 13 waiting, 1 being served.
#   Queue 2: 9 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 75.61: departure for passenger 71 at queue 2
# 	 Scheduled Timestamp (minutes) 76.19: departure for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 77.08: departure for passenger 62 at queue 1
#
#
# Airport at time (minutes) 75.612: 29 total waiting, 3 total being served
#   Queue 1: 13 waiting, 1 being served.
#   Queue 2: 8 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 76.19: departure for passenger 73 at queue 3
# 	 Scheduled Timestamp (minutes) 77.08: departure for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 78.76: departure for passenger 75 at queue 2
#
#
# Airport at time (minutes) 76.19: 28 total waiting, 3 total being served
#   Queue 1: 13 waiting, 1 being served.
#   Queue 2: 8 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 77.08: departure for passenger 62 at queue 1
# 	 Scheduled Timestamp (minutes) 78.76: departure for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 79.23: departure for passenger 76 at queue 3
#
#
# Airport at time (minutes) 77.081: 27 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 8 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 78.76: departure for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 79.23: departure for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 80.7: departure for passenger 65 at queue 1
#
#
# Airport at time (minutes) 78.757: 26 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 79.23: departure for passenger 76 at queue 3
# 	 Scheduled Timestamp (minutes) 80.7: departure for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 81.9: departure for passenger 78 at queue 2
#
#
# Airport at time (minutes) 79.231: 25 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 80.7: departure for passenger 65 at queue 1
# 	 Scheduled Timestamp (minutes) 81.9: departure for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 82.27: departure for passenger 81 at queue 3
#
#
# Airport at time (minutes) 80.696: 24 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 81.9: departure for passenger 78 at queue 2
# 	 Scheduled Timestamp (minutes) 82.27: departure for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 84.31: departure for passenger 67 at queue 1
#
#
# Airport at time (minutes) 81.901: 23 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 82.27: departure for passenger 81 at queue 3
# 	 Scheduled Timestamp (minutes) 84.31: departure for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 85.05: departure for passenger 79 at queue 2
#
#
# Airport at time (minutes) 82.272: 22 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 84.31: departure for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 85.05: departure for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 85.31: departure for passenger 84 at queue 3
#
#
# Airport at time (minutes) 84.312: 21 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 85.05: departure for passenger 79 at queue 2
# 	 Scheduled Timestamp (minutes) 85.31: departure for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 87.93: departure for passenger 70 at queue 1
#
#
# Airport at time (minutes) 85.045: 20 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 5 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 85.31: departure for passenger 84 at queue 3
# 	 Scheduled Timestamp (minutes) 87.93: departure for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 88.19: departure for passenger 82 at queue 2
#
#
# Airport at time (minutes) 85.313: 19 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 5 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 87.93: departure for passenger 70 at queue 1
# 	 Scheduled Timestamp (minutes) 88.19: departure for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 88.35: departure for passenger 87 at queue 3
#
#
# Airport at time (minutes) 87.928: 18 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 5 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 88.19: departure for passenger 82 at queue 2
# 	 Scheduled Timestamp (minutes) 88.35: departure for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 91.54: departure for passenger 74 at queue 1
#
#
# Airport at time (minutes) 88.19: 17 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 88.35: departure for passenger 87 at queue 3
# 	 Scheduled Timestamp (minutes) 91.33: departure for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 91.54: departure for passenger 74 at queue 1
#
#
# Airport at time (minutes) 88.353: 16 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 3 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 91.33: departure for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 91.39: departure for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 91.54: departure for passenger 74 at queue 1
#
#
# Airport at time (minutes) 91.334: 15 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 3 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 91.39: departure for passenger 90 at queue 3
# 	 Scheduled Timestamp (minutes) 91.54: departure for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 94.48: departure for passenger 88 at queue 2
#
#
# Airport at time (minutes) 91.394: 14 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 2 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 91.54: departure for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 94.44: departure for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 94.48: departure for passenger 88 at queue 2
#
#
# Airport at time (minutes) 91.543: 13 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 2 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 94.44: departure for passenger 93 at queue 3
# 	 Scheduled Timestamp (minutes) 94.48: departure for passenger 88 at queue 2
# 	 Scheduled Timestamp (minutes) 95.16: departure for passenger 77 at queue 1
#
#
# Airport at time (minutes) 94.435: 12 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 94.48: departure for passenger 88 at queue 2
# 	 Scheduled Timestamp (minutes) 95.16: departure for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 97.48: departure for passenger 96 at queue 3
#
#
# Airport at time (minutes) 94.478: 11 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 95.16: departure for passenger 77 at queue 1
# 	 Scheduled Timestamp (minutes) 97.48: departure for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 97.62: departure for passenger 92 at queue 2
#
#
# Airport at time (minutes) 95.159: 10 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 97.48: departure for passenger 96 at queue 3
# 	 Scheduled Timestamp (minutes) 97.62: departure for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 98.77: departure for passenger 80 at queue 1
#
#
# Airport at time (minutes) 97.476: 9 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 97.62: departure for passenger 92 at queue 2
# 	 Scheduled Timestamp (minutes) 98.77: departure for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 100.52: departure for passenger 99 at queue 3
#
#
# Airport at time (minutes) 97.623: 8 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 98.77: departure for passenger 80 at queue 1
# 	 Scheduled Timestamp (minutes) 100.52: departure for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 100.77: departure for passenger 94 at queue 2
#
#
# Airport at time (minutes) 98.775: 7 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 100.52: departure for passenger 99 at queue 3
# 	 Scheduled Timestamp (minutes) 100.77: departure for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 102.39: departure for passenger 83 at queue 1
#
#
# Airport at time (minutes) 100.517: 7 total waiting, 2 total being served
#   Queue 1: 6 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 100.77: departure for passenger 94 at queue 2
# 	 Scheduled Timestamp (minutes) 102.39: departure for passenger 83 at queue 1
#
#
# Airport at time (minutes) 100.767: 6 total waiting, 2 total being served
#   Queue 1: 6 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 102.39: departure for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 103.91: departure for passenger 97 at queue 2
#
#
# Airport at time (minutes) 102.391: 5 total waiting, 2 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 103.91: departure for passenger 97 at queue 2
# 	 Scheduled Timestamp (minutes) 106.01: departure for passenger 86 at queue 1
#
#
# Airport at time (minutes) 103.911: 5 total waiting, 1 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 106.01: departure for passenger 86 at queue 1
#
#
# Airport at time (minutes) 106.006: 4 total waiting, 1 total being served
#   Queue 1: 4 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 [Additional Screening] Scheduled Timestamp (minutes) 110.75: departure for passenger 89 at queue 1
#
#
# Airport at time (minutes) 110.746: 3 total waiting, 1 total being served
#   Queue 1: 3 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 114.36: departure for passenger 91 at queue 1
#
#
# Airport at time (minutes) 114.362: 2 total waiting, 1 total being served
#   Queue 1: 2 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 117.98: departure for passenger 95 at queue 1
#
#
# Airport at time (minutes) 117.977: 1 total waiting, 1 total being served
#   Queue 1: 1 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 121.59: departure for passenger 98 at queue 1
#
#
# Airport at time (minutes) 121.593: 0 total waiting, 1 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
# 	 Scheduled Timestamp (minutes) 125.21: departure for passenger 100 at queue 1
#
#
# Airport at time (minutes) 125.209: 0 total waiting, 0 total being served
#   Queue 1: 0 waiting, 0 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 2 needed it so far.
