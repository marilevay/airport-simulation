# %% [markdown]
# # Additional Tests for the Simulation

# %%
from simulation import Airport, Queue, run_simulation, Passenger
import numpy as np
import random

# %% [markdown]
# ## Test 1
# If the passengers are being allocated to the additional service 3% of the time

# %%
queue = Queue(timestamp=0, service_rate=1/2)
additional_service_count = 0
run_until = 10000 # number of samples

for _ in range(run_until):
    if queue.needs_additional_screening():
        additional_service_count += 1

proportion = additional_service_count / run_until
print(f"Proportion needing additional screening: {proportion:.2f}")

# Calculate confidence interval
z_score = 1.96  # for 95% confidence
margin_of_error = z_score * np.sqrt(proportion * (1 - proportion) / run_until)
confidence_interval = (proportion - margin_of_error, proportion + margin_of_error)
print(f"95% confidence interval: {confidence_interval}")
# Out:
# Proportion needing additional screening: 0.03
# 95% confidence interval: (0.027034968247638666, 0.033765031752361334)

# %%
# Alternative way to test this
queue_multi, arrivals_multi, completed_passengers = run_simulation(arrival_rate=10, service_rate=1/2, run_until=1000, num_queues=3)

# Count passengers who needed additional screening
additional_screening_count = sum(1 for passenger in completed_passengers if passenger.needs_additional_screening)

total_passengers = len(completed_passengers)
proportion = additional_screening_count / total_passengers if total_passengers > 0 else 0

print(f"Passengers needing additional screening: {additional_screening_count}/{total_passengers} ({proportion:.1%})")
# Out:
# Passengers needing additional screening: 31/1000 (3.1%)

# %% [markdown]
# ## Test 2
# Check whether passengers are being assigned to the shortest queue

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3]  # 1 passenger
airport.passenger_queues[2].waiting = [passenger4, passenger5, passenger6]  # 3 passengers

# Find shortest queue
shortest_queue = airport.find_shortest_queue()
shortest_index = airport.passenger_queues.index(shortest_queue)
print(f"Shortest queue index: {shortest_index}, with {len(shortest_queue.waiting)} passengers waiting")

# Verify it's actually the shortest
queue_lengths = [q.total_passengers() for q in airport.passenger_queues]
print(f"All queue lengths: {queue_lengths}")
print(f"Test passed: {queue_lengths[shortest_index] == min(queue_lengths)}")
# Out:
# Shortest queue index: 1, with 1 passengers waiting
# All queue lengths: [2, 1, 3]
# Test passed: True

# %% [markdown]
# ## Test 3
# Check if passengers are randomly assigned to a queue when all queues are the same length

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3, passenger4]  # 2 passengers
airport.passenger_queues[2].waiting = [passenger5, passenger6]  # 2 passengers

# Here, we want to test if the proportion of passengers assigned to each queue is roughly equal over many trials
num_trials = 1000
selected_indices = []

for _ in range(num_trials):
    selected_queue = airport.find_shortest_queue()
    selected_index = airport.passenger_queues.index(selected_queue)
    selected_indices.append(selected_index)

# Count how many times each queue was selected
queue_0_count = selected_indices.count(0)
queue_1_count = selected_indices.count(1)
queue_2_count = selected_indices.count(2)

perc_1 = (queue_0_count/num_trials)*100
perc_2 = (queue_1_count/num_trials)*100
perc_3 = (queue_2_count/num_trials)*100

print(f"Queue selection distribution over {num_trials} trials:")
print(f"Queue 0: {queue_0_count} times ({perc_1:.1f}%)")
print(f"Queue 1: {queue_1_count} times ({perc_2:.1f}%)")
print(f"Queue 2: {queue_2_count} times ({perc_3:.1f}%)")
# Out:
# Queue selection distribution over 1000 trials:
# Queue 0: 314 times (31.4%)
# Queue 1: 331 times (33.1%)
# Queue 2: 355 times (35.5%)

# %% [markdown]
# ## Test 4
# Testing queue placing dynamics, meant to check whether:
# * There are unique arrival and departure events ofr each new passenger
# * When a passenger arrives, they are placed on the shortest queue or assigned at random when all queues have the same length
# * When a passenger leaves, according to the scheduled time, they leave the queue completely

# %%
# Parameters
run_until = 100
num_queues = 3
avg_waiting_times = []
arrival_rate = 10 # minutes
service_rate = 1/2 # minutes

airport = Airport(arrival_rate, service_rate, num_queues)

# Schedule the specified number of arrivals
current_time = 0
for _ in range(run_until):
    airport.add_arrival(current_time)
    current_time = airport.curr_arrival_time  # Use the scheduled arrival time for next scheduling
    
while airport.priority_q:
    airport.run_next_service()
    airport.print_schedule()
# Out:
# Airport at time (minutes) 0.017: 99 total waiting, 1 total being served
#   Queue 1: 33 waiting, 0 being served and 0 needed additional screening so far.
#   Queue 2: 33 waiting, 0 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.04: arrival for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 0.28: arrival for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 0.29: arrival for passenger 4 at queue 0
# 	 Scheduled Timestamp (minutes) 0.36: arrival for passenger 5 at queue 1
# 	 Scheduled Timestamp (minutes) 0.39: arrival for passenger 6 at queue 2
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.04: 98 total waiting, 2 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 33 waiting, 0 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.28: arrival for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 0.29: arrival for passenger 4 at queue 0
# 	 Scheduled Timestamp (minutes) 0.36: arrival for passenger 5 at queue 1
# 	 Scheduled Timestamp (minutes) 0.39: arrival for passenger 6 at queue 2
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.281: 97 total waiting, 3 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.29: arrival for passenger 4 at queue 0
# 	 Scheduled Timestamp (minutes) 0.36: arrival for passenger 5 at queue 1
# 	 Scheduled Timestamp (minutes) 0.39: arrival for passenger 6 at queue 2
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.45: departure for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.294: 97 total waiting, 3 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.36: arrival for passenger 5 at queue 1
# 	 Scheduled Timestamp (minutes) 0.39: arrival for passenger 6 at queue 2
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.45: departure for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.363: 97 total waiting, 3 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.39: arrival for passenger 6 at queue 2
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.45: departure for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.39: 97 total waiting, 3 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.44: arrival for passenger 7 at queue 0
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# 	 Scheduled Timestamp (minutes) 3.3: departure for passenger 1 at queue 2
# 	 Scheduled Timestamp (minutes) 3.33: arrival for passenger 32 at queue 0
# 	 Scheduled Timestamp (minutes) 3.37: arrival for passenger 33 at queue 2
# 	 Scheduled Timestamp (minutes) 3.45: departure for passenger 3 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 34 at queue 1
# 	 Scheduled Timestamp (minutes) 3.48: arrival for passenger 35 at queue 0
# 	 Scheduled Timestamp (minutes) 3.61: arrival for passenger 36 at queue 2
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 37 at queue 1
# 	 Scheduled Timestamp (minutes) 3.76: arrival for passenger 38 at queue 0
# 	 Scheduled Timestamp (minutes) 3.77: arrival for passenger 39 at queue 2
# 	 Scheduled Timestamp (minutes) 3.79: arrival for passenger 40 at queue 1
# 	 Scheduled Timestamp (minutes) 3.85: arrival for passenger 41 at queue 0
# 	 Scheduled Timestamp (minutes) 3.88: arrival for passenger 42 at queue 2
# 	 Scheduled Timestamp (minutes) 4.31: arrival for passenger 43 at queue 2
# 	 Scheduled Timestamp (minutes) 4.45: arrival for passenger 44 at queue 0
# 	 Scheduled Timestamp (minutes) 4.51: arrival for passenger 45 at queue 1
# 	 Scheduled Timestamp (minutes) 4.65: arrival for passenger 46 at queue 0
# 	 Scheduled Timestamp (minutes) 4.71: arrival for passenger 47 at queue 1
# 	 Scheduled Timestamp (minutes) 4.74: arrival for passenger 48 at queue 2
# 	 Scheduled Timestamp (minutes) 4.76: arrival for passenger 49 at queue 0
# 	 Scheduled Timestamp (minutes) 4.86: arrival for passenger 50 at queue 1
# 	 Scheduled Timestamp (minutes) 4.9: arrival for passenger 51 at queue 2
# 	 Scheduled Timestamp (minutes) 5.05: arrival for passenger 52 at queue 1
# 	 Scheduled Timestamp (minutes) 5.22: arrival for passenger 53 at queue 0
# 	 Scheduled Timestamp (minutes) 5.24: arrival for passenger 54 at queue 2
# 	 Scheduled Timestamp (minutes) 5.34: arrival for passenger 55 at queue 2
# 	 Scheduled Timestamp (minutes) 5.37: arrival for passenger 56 at queue 0
# 	 Scheduled Timestamp (minutes) 5.46: arrival for passenger 57 at queue 1
# 	 Scheduled Timestamp (minutes) 5.64: arrival for passenger 58 at queue 1
# 	 Scheduled Timestamp (minutes) 5.79: arrival for passenger 59 at queue 0
# 	 Scheduled Timestamp (minutes) 5.92: arrival for passenger 60 at queue 2
# 	 Scheduled Timestamp (minutes) 5.95: arrival for passenger 61 at queue 1
# 	 Scheduled Timestamp (minutes) 6.13: arrival for passenger 62 at queue 0
# 	 Scheduled Timestamp (minutes) 6.19: arrival for passenger 63 at queue 2
# 	 Scheduled Timestamp (minutes) 6.2: arrival for passenger 64 at queue 1
# 	 Scheduled Timestamp (minutes) 6.23: arrival for passenger 65 at queue 0
# 	 Scheduled Timestamp (minutes) 6.27: arrival for passenger 66 at queue 2
# 	 Scheduled Timestamp (minutes) 6.41: arrival for passenger 67 at queue 1
# 	 Scheduled Timestamp (minutes) 6.7: arrival for passenger 68 at queue 0
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 69 at queue 2
# 	 Scheduled Timestamp (minutes) 6.82: arrival for passenger 70 at queue 2
# 	 Scheduled Timestamp (minutes) 6.9: arrival for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 72 at queue 1
# 	 Scheduled Timestamp (minutes) 7.34: arrival for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 7.44: arrival for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 7.5: arrival for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 7.52: arrival for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 7.55: arrival for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 7.57: arrival for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 7.86: arrival for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 7.95: arrival for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 8.04: arrival for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 8.14: arrival for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 8.23: arrival for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 8.44: arrival for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 8.8: arrival for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 8.82: arrival for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 8.84: arrival for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 9.15: arrival for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 9.26: arrival for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 9.33: arrival for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 9.41: arrival for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 9.5: arrival for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 9.73: arrival for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 10.19: arrival for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 10.25: arrival for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 10.27: arrival for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 10.28: arrival for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 10.39: arrival for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 10.58: arrival for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 10.66: arrival for passenger 100 at queue 2
#
#
# Airport at time (minutes) 0.441: 97 total waiting, 3 total being served
#   Queue 1: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 2: 32 waiting, 1 being served and 0 needed additional screening so far.
#   Queue 3: 33 waiting, 1 being served and 0 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 0.57: arrival for passenger 8 at queue 1
# 	 Scheduled Timestamp (minutes) 0.86: arrival for passenger 9 at queue 2
# 	 Scheduled Timestamp (minutes) 0.89: arrival for passenger 10 at queue 1
# 	 Scheduled Timestamp (minutes) 0.99: arrival for passenger 11 at queue 0
# 	 Scheduled Timestamp (minutes) 1.2: arrival for passenger 12 at queue 2
# 	 Scheduled Timestamp (minutes) 1.27: arrival for passenger 13 at queue 0
# 	 Scheduled Timestamp (minutes) 1.33: arrival for passenger 14 at queue 1
# 	 Scheduled Timestamp (minutes) 1.52: arrival for passenger 15 at queue 2
# 	 Scheduled Timestamp (minutes) 1.59: arrival for passenger 16 at queue 2
# 	 Scheduled Timestamp (minutes) 1.68: arrival for passenger 17 at queue 0
# 	 Scheduled Timestamp (minutes) 1.79: arrival for passenger 18 at queue 1
# 	 Scheduled Timestamp (minutes) 1.84: arrival for passenger 19 at queue 2
# 	 Scheduled Timestamp (minutes) 1.89: arrival for passenger 20 at queue 0
# 	 Scheduled Timestamp (minutes) 1.93: arrival for passenger 21 at queue 1
# 	 Scheduled Timestamp (minutes) 2.02: arrival for passenger 22 at queue 0
# 	 Scheduled Timestamp (minutes) 2.06: arrival for passenger 23 at queue 1
# 	 Scheduled Timestamp (minutes) 2.07: arrival for passenger 24 at queue 2
# 	 Scheduled Timestamp (minutes) 2.32: arrival for passenger 25 at queue 1
# 	 Scheduled Timestamp (minutes) 2.58: arrival for passenger 26 at queue 0
# 	 Scheduled Timestamp (minutes) 2.63: arrival for passenger 27 at queue 2
# 	 Scheduled Timestamp (minutes) 2.75: arrival for passenger 28 at queue 1
# 	 Scheduled Timestamp (minutes) 2.97: arrival for passenger 29 at queue 0
# 	 Scheduled Timestamp (minutes) 3.05: departure for passenger 2 at queue 0
# 	 Scheduled Timestamp (minutes) 3.1: arrival for passenger 30 at queue 2
# 	 Scheduled Timestamp (minutes) 3.18: arrival for passenger 31 at queue 1
# ...
# 	 Scheduled Timestamp (minutes) 83.3: departure for passenger 75 at queue 2
#
#
# Airport at time (minutes) 80.628: 26 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 2: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 3: 9 waiting, 1 being served and 2 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 80.79: departure for passenger 71 at queue 0
# 	 Scheduled Timestamp (minutes) 83.3: departure for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 83.89: departure for passenger 74 at queue 1
#
#
# Airport at time (minutes) 80.79: 25 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 2: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 3: 9 waiting, 1 being served and 2 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 83.3: departure for passenger 75 at queue 2
# 	 Scheduled Timestamp (minutes) 83.89: departure for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 85.27: departure for passenger 73 at queue 0
#
#
# Airport at time (minutes) 83.295: 24 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 2: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 3: 8 waiting, 1 being served and 2 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 83.89: departure for passenger 74 at queue 1
# 	 Scheduled Timestamp (minutes) 85.27: departure for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 86.76: departure for passenger 76 at queue 2
#
#
# Airport at time (minutes) 83.893: 23 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 2: 7 waiting, 1 being served and 2 needed additional screening so far.
#   Queue 3: 8 waiting, 1 being served and 2 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 85.27: departure for passenger 73 at queue 0
# 	 Scheduled Timestamp (minutes) 86.76: departure for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 78 at queue 1
#
#
# Airport at time (minutes) 85.274: 22 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 2: 7 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 3: 8 waiting, 1 being served and 3 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 86.76: departure for passenger 76 at queue 2
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 78 at queue 1
#
#
# Airport at time (minutes) 86.756: 21 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 2: 7 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 3: 7 waiting, 1 being served and 3 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 77 at queue 0
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 89.76: departure for passenger 81 at queue 2
#
#
# Airport at time (minutes) 88.543: 20 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 2: 7 waiting, 1 being served and 3 needed additional screening so far.
#   Queue 3: 7 waiting, 1 being served and 3 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 88.54: departure for passenger 78 at queue 1
# 	 Scheduled Timestamp (minutes) 89.76: departure for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 91.56: departure for passenger 80 at queue 0
#
#
# Airport at time (minutes) 88.544: 19 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 6 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 7 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 89.76: departure for passenger 81 at queue 2
# 	 Scheduled Timestamp (minutes) 91.56: departure for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 91.62: departure for passenger 79 at queue 1
#
#
# Airport at time (minutes) 89.758: 18 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 6 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 6 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 91.56: departure for passenger 80 at queue 0
# 	 Scheduled Timestamp (minutes) 91.62: departure for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 92.96: departure for passenger 84 at queue 2
#
#
# Airport at time (minutes) 91.562: 17 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 6 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 6 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 91.62: departure for passenger 79 at queue 1
# 	 Scheduled Timestamp (minutes) 92.96: departure for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 94.63: departure for passenger 82 at queue 0
#
#
# Airport at time (minutes) 91.619: 16 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 6 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 92.96: departure for passenger 84 at queue 2
# 	 Scheduled Timestamp (minutes) 94.63: departure for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 94.94: departure for passenger 83 at queue 1
#
#
# Airport at time (minutes) 92.963: 15 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 5 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 94.63: departure for passenger 82 at queue 0
# 	 Scheduled Timestamp (minutes) 94.94: departure for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 96.08: departure for passenger 85 at queue 2
#
#
# Airport at time (minutes) 94.632: 14 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 5 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 5 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 94.94: departure for passenger 83 at queue 1
# 	 Scheduled Timestamp (minutes) 96.08: departure for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 97.94: departure for passenger 86 at queue 0
#
#
# Airport at time (minutes) 94.937: 13 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 5 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 96.08: departure for passenger 85 at queue 2
# 	 Scheduled Timestamp (minutes) 97.94: departure for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 98.13: departure for passenger 87 at queue 1
#
#
# Airport at time (minutes) 96.078: 12 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 4 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 97.94: departure for passenger 86 at queue 0
# 	 Scheduled Timestamp (minutes) 98.13: departure for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 99.68: departure for passenger 90 at queue 2
#
#
# Airport at time (minutes) 97.944: 11 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 4 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 4 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 98.13: departure for passenger 87 at queue 1
# 	 Scheduled Timestamp (minutes) 99.68: departure for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 101.73: departure for passenger 89 at queue 0
#
#
# Airport at time (minutes) 98.131: 10 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 4 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 99.68: departure for passenger 90 at queue 2
# 	 Scheduled Timestamp (minutes) 101.35: departure for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 101.73: departure for passenger 89 at queue 0
#
#
# Airport at time (minutes) 99.676: 9 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 3 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 101.35: departure for passenger 88 at queue 1
# 	 Scheduled Timestamp (minutes) 101.73: departure for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 103.0: departure for passenger 91 at queue 2
#
#
# Airport at time (minutes) 101.349: 8 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 3 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 101.73: departure for passenger 89 at queue 0
# 	 Scheduled Timestamp (minutes) 103.0: departure for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 104.51: departure for passenger 93 at queue 1
#
#
# Airport at time (minutes) 101.728: 7 total waiting, 3 total being served
#   Queue 1: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 3 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 103.0: departure for passenger 91 at queue 2
# 	 Scheduled Timestamp (minutes) 104.51: departure for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 105.14: departure for passenger 92 at queue 0
#
#
# Airport at time (minutes) 103.002: 6 total waiting, 3 total being served
#   Queue 1: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 2 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 104.51: departure for passenger 93 at queue 1
# 	 Scheduled Timestamp (minutes) 105.14: departure for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 106.02: departure for passenger 96 at queue 2
#
#
# Airport at time (minutes) 104.514: 5 total waiting, 3 total being served
#   Queue 1: 2 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 2 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 105.14: departure for passenger 92 at queue 0
# 	 Scheduled Timestamp (minutes) 106.02: departure for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 107.69: departure for passenger 95 at queue 1
#
#
# Airport at time (minutes) 105.144: 4 total waiting, 3 total being served
#   Queue 1: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 2 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 106.02: departure for passenger 96 at queue 2
# 	 Scheduled Timestamp (minutes) 107.69: departure for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 108.63: departure for passenger 94 at queue 0
#
#
# Airport at time (minutes) 106.024: 3 total waiting, 3 total being served
#   Queue 1: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 1 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 107.69: departure for passenger 95 at queue 1
# 	 Scheduled Timestamp (minutes) 108.63: departure for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 109.84: departure for passenger 99 at queue 2
#
#
# Airport at time (minutes) 107.693: 2 total waiting, 3 total being served
#   Queue 1: 1 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 1 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 108.63: departure for passenger 94 at queue 0
# 	 Scheduled Timestamp (minutes) 109.84: departure for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 110.87: departure for passenger 97 at queue 1
#
#
# Airport at time (minutes) 108.629: 1 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 1 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 109.84: departure for passenger 99 at queue 2
# 	 Scheduled Timestamp (minutes) 110.87: departure for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 112.55: departure for passenger 98 at queue 0
#
#
# Airport at time (minutes) 109.841: 0 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 3: 0 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 110.87: departure for passenger 97 at queue 1
# 	 Scheduled Timestamp (minutes) 112.55: departure for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 113.99: departure for passenger 100 at queue 2
#
#
# Airport at time (minutes) 110.872: 0 total waiting, 2 total being served
#   Queue 1: 0 waiting, 1 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 0 being served and 4 needed additional screening so far.
#   Queue 3: 0 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 112.55: departure for passenger 98 at queue 0
# 	 Scheduled Timestamp (minutes) 113.99: departure for passenger 100 at queue 2
#
#
# Airport at time (minutes) 112.545: 0 total waiting, 1 total being served
#   Queue 1: 0 waiting, 0 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 0 being served and 4 needed additional screening so far.
#   Queue 3: 0 waiting, 1 being served and 4 needed additional screening so far.
# 	 Scheduled Timestamp (minutes) 113.99: departure for passenger 100 at queue 2
#
#
# Airport at time (minutes) 113.986: 0 total waiting, 0 total being served
#   Queue 1: 0 waiting, 0 being served and 4 needed additional screening so far.
#   Queue 2: 0 waiting, 0 being served and 4 needed additional screening so far.
#   Queue 3: 0 waiting, 0 being served and 4 needed additional screening so far.
