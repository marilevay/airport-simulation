# %% [markdown]
# # Additional Tests for the Simulation

# %% [markdown]
# ## Imports

# %%
from simulation.classes import Airport, Queue, Passenger
from simulation.helpers import run_simulation
import numpy as np

# %% [markdown]
# ## Test 1
# If the passengers are being allocated to the additional service 3% of the time

# %%
queue = Queue(timestamp=0, service_rate=1/2)
additional_service_count = 0
run_until = 10000 # number of samples

for i in range(run_until):
    # create a new passenger for each trial
    passenger = Passenger(id=i, arrival_time=0)
    if passenger.needs_additional_screening:
        additional_service_count += 1
        
proportion = additional_service_count / run_until
print(f"Proportion needing additional screening: {proportion:.2f}")

# Calculate confidence interval
z_score = 1.96  # for 95% confidence
margin_of_error = z_score * np.sqrt(proportion * (1 - proportion) / run_until)
confidence_interval = (proportion - margin_of_error, proportion + margin_of_error)
print(f"95% confidence interval: {confidence_interval}")
# Out:
# Proportion needing additional screening: 0.03
# 95% confidence interval: (0.026278170628343474, 0.03292182937165653)

# %%
# Alternative way to test this
avg_queue_lens, arrival_times, all_passengers, max_queue_length = run_simulation(arrival_rate=10, service_rate=1/2, service_distribution=None, additional_screening_distribution=None, run_until=1000, num_queues=3)

# Count passengers who needed additional screening
additional_screening_count = sum(1 for p in all_passengers.values() if p.needs_additional_screening)

total_passengers = len(all_passengers)
proportion = additional_screening_count / total_passengers if total_passengers > 0 else 0

print(f"Passengers needing additional screening: {additional_screening_count}/{total_passengers} ({proportion:.1%})")
# Out:
# Passengers needing additional screening: 31/1000 (3.1%)

# %% [markdown]
# ## Test 2
# Check whether passengers are being assigned to the shortest queue

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3]  # 1 passenger
airport.passenger_queues[2].waiting = [passenger4, passenger5, passenger6]  # 3 passengers

# Find shortest queue
shortest_queue = airport.find_shortest_queue()
shortest_index = airport.passenger_queues.index(shortest_queue)
print(f"Shortest queue index: {shortest_index}, with {len(shortest_queue.waiting)} passengers waiting")

# Verify it's actually the shortest
queue_lengths = [q.total_passengers() for q in airport.passenger_queues]
print(f"All queue lengths: {queue_lengths}")
print(f"Test passed: {queue_lengths[shortest_index] == min(queue_lengths)}")
# Out:
# Shortest queue index: 1, with 1 passengers waiting
# All queue lengths: [2, 1, 3]
# Test passed: True

# %% [markdown]
# ## Test 3
# Check if passengers are randomly assigned to a queue when all queues are the same length. Here, we want to test if the proportion of passengers assigned to each queue is roughly equal over many trials.

# %%
airport = Airport(arrival_rate=10, service_rate=1/2, num_queues=3)

# creating passenger objects
passenger1 = Passenger(1, arrival_time=0)
passenger2 = Passenger(2, arrival_time=1)
passenger3 = Passenger(3, arrival_time=2)
passenger4 = Passenger(4, arrival_time=3)
passenger5 = Passenger(5, arrival_time=4)
passenger6 = Passenger(6, arrival_time=5)

# Add passengers to queues manually to test shortest queue selection
airport.passenger_queues[0].waiting = [passenger1, passenger2]  # 2 passengers
airport.passenger_queues[1].waiting = [passenger3, passenger4]  # 2 passengers
airport.passenger_queues[2].waiting = [passenger5, passenger6]  # 2 passengers

num_trials = 1000
selected_indices = []

for _ in range(num_trials):
    selected_queue = airport.find_shortest_queue()
    selected_index = airport.passenger_queues.index(selected_queue)
    selected_indices.append(selected_index)

# Count how many times each queue was selected
queue_0_count = selected_indices.count(0)
queue_1_count = selected_indices.count(1)
queue_2_count = selected_indices.count(2)

perc_1 = (queue_0_count/num_trials)*100
perc_2 = (queue_1_count/num_trials)*100
perc_3 = (queue_2_count/num_trials)*100

print(f"Queue selection distribution over {num_trials} trials:")
print(f"Queue 0: {queue_0_count} times ({perc_1:.1f}%)")
print(f"Queue 1: {queue_1_count} times ({perc_2:.1f}%)")
print(f"Queue 2: {queue_2_count} times ({perc_3:.1f}%)")
# Out:
# Queue selection distribution over 1000 trials:
# Queue 0: 333 times (33.3%)
# Queue 1: 322 times (32.2%)
# Queue 2: 345 times (34.5%)

# %% [markdown]
# ## Test 4
# Testing queue placing dynamics, meant to check whether:
# * There are unique arrival and departure events for each new passenger
# * When a passenger arrives, they are placed on the shortest queue or assigned at random when all queues have the same length
# * When a passenger leaves, according to the scheduled time, they leave the queue completely

# %%
# Parameters
run_until = 100
num_queues = 3
avg_waiting_times = []
arrival_rate = 10 # minutes
service_rate = 1/2 # minutes

airport = Airport(arrival_rate, service_rate, num_queues)

# Schedule the specified number of arrivals
current_time = 0
for _ in range(run_until):
    airport.add_arrival(current_time)
    current_time = airport.curr_arrival_time  # Use the scheduled arrival time for next scheduling

# Initial schedule before any service
airport.print_schedule() 
    
while airport.priority_q:
    airport.run_next_service()
    airport.print_schedule()
# Out:
# Airport at time (minutes) 0: 0 total waiting, 0 total being served
#   Queue 1: 0 waiting, 0 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.21: Passenger 1 → Queue None
# 	[Arrival]    t=0.28: Passenger 2 → Queue None
# 	[Arrival]    t=0.31: Passenger 3 → Queue None
# 	[Arrival]    t=0.31: Passenger 4 → Queue None
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.208: 0 total waiting, 1 total being served
#   Queue 1: 0 waiting, 0 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.28: Passenger 2 → Queue None
# 	[Arrival]    t=0.31: Passenger 3 → Queue None
# 	[Arrival]    t=0.31: Passenger 4 → Queue None
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.281: 0 total waiting, 2 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.31: Passenger 3 → Queue None
# 	[Arrival]    t=0.31: Passenger 4 → Queue None
# 	[Departure]  t=0.35: Passenger 2 left Queue 1
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.31: 0 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.31: Passenger 4 → Queue None
# 	[Departure]  t=0.35: Passenger 2 left Queue 1
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.312: 1 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=0.35: Passenger 2 left Queue 1
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.351: 1 total waiting, 2 total being served
#   Queue 1: 0 waiting, 0 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.37: Passenger 5 → Queue None
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.373: 1 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.60: Passenger 6 → Queue None
# 	[Departure]  t=0.65: Passenger 5 left Queue 1
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.597: 2 total waiting, 3 total being served
#   Queue 1: 1 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=0.65: Passenger 5 left Queue 1
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.65: 1 total waiting, 3 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.70: Passenger 7 → Queue None
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Departure]  t=1.16: Passenger 6 left Queue 1
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# 	[Arrival]    t=6.70: Passenger 66 → Queue None
# 	[Arrival]    t=6.72: Passenger 67 → Queue None
# 	[Arrival]    t=6.76: Passenger 68 → Queue None
# 	[Arrival]    t=6.80: Passenger 69 → Queue None
# 	[Arrival]    t=6.85: Passenger 70 → Queue None
# 	[Arrival]    t=7.06: Passenger 71 → Queue None
# 	[Arrival]    t=7.07: Passenger 72 → Queue None
# 	[Arrival]    t=7.17: Passenger 73 → Queue None
# 	[Arrival]    t=7.22: Passenger 74 → Queue None
# 	[Arrival]    t=7.33: Passenger 75 → Queue None
# 	[Arrival]    t=7.45: Passenger 76 → Queue None
# 	[Arrival]    t=7.58: Passenger 77 → Queue None
# 	[Arrival]    t=7.59: Passenger 78 → Queue None
# 	[Arrival]    t=7.71: Passenger 79 → Queue None
# 	[Arrival]    t=7.75: Passenger 80 → Queue None
# 	[Arrival]    t=7.78: Passenger 81 → Queue None
# 	[Arrival]    t=7.96: Passenger 82 → Queue None
# 	[Arrival]    t=7.97: Passenger 83 → Queue None
# 	[Arrival]    t=8.07: Passenger 84 → Queue None
# 	[Arrival]    t=8.15: Passenger 85 → Queue None
# 	[Arrival]    t=8.18: Passenger 86 → Queue None
# 	[Arrival]    t=8.21: Passenger 87 → Queue None
# 	[Arrival]    t=8.22: Passenger 88 → Queue None
# 	[Arrival]    t=8.30: Passenger 89 → Queue None
# 	[Arrival]    t=8.56: Passenger 90 → Queue None
# 	[Arrival]    t=8.92: Passenger 91 → Queue None
# 	[Arrival]    t=8.97: Passenger 92 → Queue None
# 	[Arrival]    t=9.29: Passenger 93 → Queue None
# 	[Arrival]    t=9.34: Passenger 94 → Queue None
# 	[Arrival]    t=9.41: Passenger 95 → Queue None
# 	[Arrival]    t=9.95: Passenger 96 → Queue None
# 	[Arrival]    t=10.27: Passenger 97 → Queue None
# 	[Arrival]    t=10.34: Passenger 98 → Queue None
# 	[Arrival]    t=10.40: Passenger 99 → Queue None
# 	[Arrival]    t=10.51: Passenger 100 → Queue None
#
#
# Airport at time (minutes) 0.703: 2 total waiting, 3 total being served
#   Queue 1: 1 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Arrival]    t=0.72: Passenger 8 → Queue None
# 	[Arrival]    t=0.77: Passenger 9 → Queue None
# 	[Departure]  t=0.79: Passenger 1 left Queue 2
# 	[Arrival]    t=0.85: Passenger 10 → Queue None
# 	[Departure]  t=0.88: Passenger 3 left Queue 3 (needs screening)
# 	[Arrival]    t=0.95: Passenger 11 → Queue None
# 	[Arrival]    t=0.99: Passenger 12 → Queue None
# 	[Arrival]    t=1.04: Passenger 13 → Queue None
# 	[Arrival]    t=1.07: Passenger 14 → Queue None
# 	[Arrival]    t=1.13: Passenger 15 → Queue None
# 	[Departure]  t=1.16: Passenger 6 left Queue 1
# 	[Arrival]    t=1.25: Passenger 16 → Queue None
# 	[Arrival]    t=1.28: Passenger 17 → Queue None
# 	[Arrival]    t=1.30: Passenger 18 → Queue None
# 	[Arrival]    t=1.31: Passenger 19 → Queue None
# 	[Arrival]    t=1.43: Passenger 20 → Queue None
# 	[Arrival]    t=1.51: Passenger 21 → Queue None
# 	[Arrival]    t=1.54: Passenger 22 → Queue None
# 	[Arrival]    t=1.60: Passenger 23 → Queue None
# 	[Arrival]    t=1.75: Passenger 24 → Queue None
# 	[Arrival]    t=2.05: Passenger 25 → Queue None
# 	[Arrival]    t=2.36: Passenger 26 → Queue None
# 	[Arrival]    t=2.48: Passenger 27 → Queue None
# 	[Arrival]    t=2.58: Passenger 28 → Queue None
# 	[Arrival]    t=2.80: Passenger 29 → Queue None
# 	[Arrival]    t=3.02: Passenger 30 → Queue None
# 	[Arrival]    t=3.03: Passenger 31 → Queue None
# 	[Arrival]    t=3.09: Passenger 32 → Queue None
# 	[Arrival]    t=3.22: Passenger 33 → Queue None
# 	[Arrival]    t=3.25: Passenger 34 → Queue None
# 	[Arrival]    t=3.39: Passenger 35 → Queue None
# 	[Arrival]    t=3.40: Passenger 36 → Queue None
# 	[Arrival]    t=3.44: Passenger 37 → Queue None
# 	[Arrival]    t=3.48: Passenger 38 → Queue None
# 	[Arrival]    t=3.74: Passenger 39 → Queue None
# 	[Arrival]    t=3.87: Passenger 40 → Queue None
# 	[Arrival]    t=3.95: Passenger 41 → Queue None
# 	[Arrival]    t=3.95: Passenger 42 → Queue None
# 	[Arrival]    t=4.33: Passenger 43 → Queue None
# 	[Arrival]    t=4.37: Passenger 44 → Queue None
# 	[Arrival]    t=4.54: Passenger 45 → Queue None
# 	[Arrival]    t=4.59: Passenger 46 → Queue None
# 	[Arrival]    t=4.85: Passenger 47 → Queue None
# 	[Arrival]    t=4.89: Passenger 48 → Queue None
# 	[Arrival]    t=4.93: Passenger 49 → Queue None
# 	[Arrival]    t=5.00: Passenger 50 → Queue None
# 	[Arrival]    t=5.01: Passenger 51 → Queue None
# 	[Arrival]    t=5.03: Passenger 52 → Queue None
# 	[Arrival]    t=5.05: Passenger 53 → Queue None
# 	[Arrival]    t=5.07: Passenger 54 → Queue None
# 	[Arrival]    t=5.43: Passenger 55 → Queue None
# 	[Arrival]    t=5.53: Passenger 56 → Queue None
# 	[Arrival]    t=5.59: Passenger 57 → Queue None
# 	[Arrival]    t=5.59: Passenger 58 → Queue None
# 	[Arrival]    t=5.66: Passenger 59 → Queue None
# 	[Arrival]    t=5.75: Passenger 60 → Queue None
# 	[Arrival]    t=5.80: Passenger 61 → Queue None
# 	[Arrival]    t=5.96: Passenger 62 → Queue None
# 	[Arrival]    t=6.23: Passenger 63 → Queue None
# 	[Arrival]    t=6.50: Passenger 64 → Queue None
# 	[Arrival]    t=6.65: Passenger 65 → Queue None
# ...
#
#
# Airport at time (minutes) 11.222: 38 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 14 waiting, 1 being served.
#   Queue 3: 12 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=11.32: Passenger 63 left Queue 2
# 	[Departure]  t=11.76: Passenger 67 left Queue 3
# 	[Departure]  t=11.90: Passenger 45 left Queue 1
#
#
# Airport at time (minutes) 11.323: 37 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 13 waiting, 1 being served.
#   Queue 3: 12 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=11.76: Passenger 67 left Queue 3
# 	[Departure]  t=11.90: Passenger 45 left Queue 1
# 	[Departure]  t=11.97: Passenger 65 left Queue 2
#
#
# Airport at time (minutes) 11.757: 36 total waiting, 3 total being served
#   Queue 1: 12 waiting, 1 being served.
#   Queue 2: 13 waiting, 1 being served.
#   Queue 3: 11 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=11.90: Passenger 45 left Queue 1
# 	[Departure]  t=11.97: Passenger 65 left Queue 2
# 	[Departure]  t=12.08: Passenger 69 left Queue 3
#
#
# Airport at time (minutes) 11.904: 35 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 13 waiting, 1 being served.
#   Queue 3: 11 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=11.97: Passenger 65 left Queue 2
# 	[Departure]  t=12.08: Passenger 69 left Queue 3
# 	[Departure]  t=12.57: Passenger 51 left Queue 1
#
#
# Airport at time (minutes) 11.967: 34 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 12 waiting, 1 being served.
#   Queue 3: 11 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=12.08: Passenger 69 left Queue 3
# 	[Departure]  t=12.40: Passenger 66 left Queue 2
# 	[Departure]  t=12.57: Passenger 51 left Queue 1
#
#
# Airport at time (minutes) 12.082: 33 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 12 waiting, 1 being served.
#   Queue 3: 10 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=12.40: Passenger 66 left Queue 2
# 	[Departure]  t=12.57: Passenger 51 left Queue 1
# 	[Departure]  t=12.68: Passenger 71 left Queue 3
#
#
# Airport at time (minutes) 12.397: 32 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 11 waiting, 1 being served.
#   Queue 3: 10 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=12.51: Passenger 68 left Queue 2
# 	[Departure]  t=12.57: Passenger 51 left Queue 1
# 	[Departure]  t=12.68: Passenger 71 left Queue 3
#
#
# Airport at time (minutes) 12.506: 31 total waiting, 3 total being served
#   Queue 1: 11 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 10 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=12.57: Passenger 51 left Queue 1
# 	[Departure]  t=12.68: Passenger 71 left Queue 3
# 	[Departure]  t=13.07: Passenger 73 left Queue 2
#
#
# Airport at time (minutes) 12.57: 30 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 10 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=12.68: Passenger 71 left Queue 3
# 	[Departure]  t=13.04: Passenger 54 left Queue 1 (needs screening)
# 	[Departure]  t=13.07: Passenger 73 left Queue 2
#
#
# Airport at time (minutes) 12.678: 29 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 9 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.03: Passenger 75 left Queue 3
# 	[Departure]  t=13.04: Passenger 54 left Queue 1 (needs screening)
# 	[Departure]  t=13.07: Passenger 73 left Queue 2
#
#
# Airport at time (minutes) 13.026: 28 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.04: Passenger 54 left Queue 1 (needs screening)
# 	[Departure]  t=13.07: Passenger 73 left Queue 2
# 	[Departure]  t=13.69: Passenger 76 left Queue 3
#
#
# Airport at time (minutes) 13.039: 28 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 10 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.07: Passenger 73 left Queue 2
# 	[Departure]  t=13.69: Passenger 76 left Queue 3
# 	[Officer]    t=13.86: Passenger 54 finished screening
#
#
# Airport at time (minutes) 13.069: 27 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 9 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.56: Passenger 74 left Queue 2
# 	[Departure]  t=13.69: Passenger 76 left Queue 3
# 	[Officer]    t=13.86: Passenger 54 finished screening
#
#
# Airport at time (minutes) 13.56: 26 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 8 waiting, 1 being served.
#   Queue 3: 8 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.69: Passenger 76 left Queue 3
# 	[Departure]  t=13.83: Passenger 77 left Queue 2
# 	[Officer]    t=13.86: Passenger 54 finished screening
#
#
# Airport at time (minutes) 13.69: 25 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 8 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=13.83: Passenger 77 left Queue 2
# 	[Officer]    t=13.86: Passenger 54 finished screening
# 	[Departure]  t=14.05: Passenger 79 left Queue 3
#
#
# Airport at time (minutes) 13.826: 24 total waiting, 3 total being served
#   Queue 1: 10 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Officer]    t=13.86: Passenger 54 finished screening
# 	[Departure]  t=14.05: Passenger 79 left Queue 3
# 	[Departure]  t=14.28: Passenger 80 left Queue 2
#
#
# Airport at time (minutes) 13.862: 23 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 7 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.05: Passenger 79 left Queue 3
# 	[Departure]  t=14.27: Passenger 62 left Queue 1
# 	[Departure]  t=14.28: Passenger 80 left Queue 2
#
#
# Airport at time (minutes) 14.046: 22 total waiting, 3 total being served
#   Queue 1: 9 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.27: Passenger 62 left Queue 1
# 	[Departure]  t=14.28: Passenger 80 left Queue 2
# 	[Departure]  t=14.62: Passenger 81 left Queue 3
#
#
# Airport at time (minutes) 14.274: 21 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 7 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.28: Passenger 80 left Queue 2
# 	[Departure]  t=14.62: Passenger 81 left Queue 3
# 	[Departure]  t=14.79: Passenger 70 left Queue 1
#
#
# Airport at time (minutes) 14.284: 20 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 6 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.62: Passenger 81 left Queue 3
# 	[Departure]  t=14.79: Passenger 70 left Queue 1
# 	[Departure]  t=14.95: Passenger 84 left Queue 2
#
#
# Airport at time (minutes) 14.623: 19 total waiting, 3 total being served
#   Queue 1: 8 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.79: Passenger 70 left Queue 1
# 	[Departure]  t=14.95: Passenger 84 left Queue 2
# 	[Departure]  t=15.25: Passenger 82 left Queue 3
#
#
# Airport at time (minutes) 14.79: 18 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 6 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=14.95: Passenger 84 left Queue 2
# 	[Departure]  t=15.25: Passenger 82 left Queue 3
# 	[Departure]  t=15.37: Passenger 72 left Queue 1
#
#
# Airport at time (minutes) 14.951: 17 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 5 waiting, 1 being served.
#   Queue 3: 5 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.25: Passenger 82 left Queue 3
# 	[Departure]  t=15.36: Passenger 86 left Queue 2
# 	[Departure]  t=15.37: Passenger 72 left Queue 1
#
#
# Airport at time (minutes) 15.255: 16 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 5 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.36: Passenger 86 left Queue 2
# 	[Departure]  t=15.37: Passenger 72 left Queue 1
# 	[Departure]  t=15.73: Passenger 85 left Queue 3
#
#
# Airport at time (minutes) 15.364: 15 total waiting, 3 total being served
#   Queue 1: 7 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.37: Passenger 72 left Queue 1
# 	[Departure]  t=15.73: Passenger 85 left Queue 3
# 	[Departure]  t=15.93: Passenger 89 left Queue 2
#
#
# Airport at time (minutes) 15.367: 14 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 4 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.73: Passenger 85 left Queue 3
# 	[Departure]  t=15.85: Passenger 78 left Queue 1
# 	[Departure]  t=15.93: Passenger 89 left Queue 2
#
#
# Airport at time (minutes) 15.726: 13 total waiting, 3 total being served
#   Queue 1: 6 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 3 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.85: Passenger 78 left Queue 1
# 	[Departure]  t=15.93: Passenger 89 left Queue 2
# 	[Departure]  t=16.22: Passenger 91 left Queue 3
#
#
# Airport at time (minutes) 15.847: 12 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 4 waiting, 1 being served.
#   Queue 3: 3 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=15.93: Passenger 89 left Queue 2
# 	[Departure]  t=16.22: Passenger 91 left Queue 3
# 	[Departure]  t=16.43: Passenger 83 left Queue 1
#
#
# Airport at time (minutes) 15.934: 11 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 3 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=16.22: Passenger 91 left Queue 3
# 	[Departure]  t=16.27: Passenger 93 left Queue 2
# 	[Departure]  t=16.43: Passenger 83 left Queue 1
#
#
# Airport at time (minutes) 16.222: 10 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 3 waiting, 1 being served.
#   Queue 3: 2 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=16.27: Passenger 93 left Queue 2
# 	[Departure]  t=16.43: Passenger 83 left Queue 1
# 	[Departure]  t=16.79: Passenger 96 left Queue 3
#
#
# Airport at time (minutes) 16.265: 9 total waiting, 3 total being served
#   Queue 1: 5 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 2 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=16.43: Passenger 83 left Queue 1
# 	[Departure]  t=16.79: Passenger 96 left Queue 3
# 	[Departure]  t=16.87: Passenger 94 left Queue 2
#
#
# Airport at time (minutes) 16.426: 8 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 2 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=16.79: Passenger 96 left Queue 3
# 	[Departure]  t=16.87: Passenger 94 left Queue 2
# 	[Departure]  t=17.17: Passenger 87 left Queue 1
#
#
# Airport at time (minutes) 16.795: 7 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served.
#   Queue 2: 2 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=16.87: Passenger 94 left Queue 2
# 	[Departure]  t=17.17: Passenger 87 left Queue 1
# 	[Departure]  t=17.49: Passenger 97 left Queue 3
#
#
# Airport at time (minutes) 16.871: 6 total waiting, 3 total being served
#   Queue 1: 4 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.17: Passenger 87 left Queue 1
# 	[Departure]  t=17.38: Passenger 98 left Queue 2
# 	[Departure]  t=17.49: Passenger 97 left Queue 3
#
#
# Airport at time (minutes) 17.165: 5 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served.
#   Queue 2: 1 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.38: Passenger 98 left Queue 2
# 	[Departure]  t=17.49: Passenger 97 left Queue 3
# 	[Departure]  t=17.83: Passenger 88 left Queue 1
#
#
# Airport at time (minutes) 17.378: 4 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 1 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.49: Passenger 97 left Queue 3
# 	[Departure]  t=17.83: Passenger 88 left Queue 1
# 	[Departure]  t=17.84: Passenger 99 left Queue 2
#
#
# Airport at time (minutes) 17.494: 3 total waiting, 3 total being served
#   Queue 1: 3 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.83: Passenger 88 left Queue 1
# 	[Departure]  t=17.84: Passenger 99 left Queue 2
# 	[Departure]  t=17.88: Passenger 100 left Queue 3
#
#
# Airport at time (minutes) 17.83: 2 total waiting, 3 total being served
#   Queue 1: 2 waiting, 1 being served.
#   Queue 2: 0 waiting, 1 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.84: Passenger 99 left Queue 2
# 	[Departure]  t=17.88: Passenger 100 left Queue 3
# 	[Departure]  t=18.50: Passenger 90 left Queue 1
#
#
# Airport at time (minutes) 17.842: 2 total waiting, 2 total being served
#   Queue 1: 2 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 1 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=17.88: Passenger 100 left Queue 3
# 	[Departure]  t=18.50: Passenger 90 left Queue 1
#
#
# Airport at time (minutes) 17.881: 2 total waiting, 1 total being served
#   Queue 1: 2 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=18.50: Passenger 90 left Queue 1
#
#
# Airport at time (minutes) 18.502: 1 total waiting, 1 total being served
#   Queue 1: 1 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=18.75: Passenger 92 left Queue 1
#
#
# Airport at time (minutes) 18.753: 0 total waiting, 1 total being served
#   Queue 1: 0 waiting, 1 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
# 	[Departure]  t=19.16: Passenger 95 left Queue 1
#
#
# Airport at time (minutes) 19.159: 0 total waiting, 0 total being served
#   Queue 1: 0 waiting, 0 being served.
#   Queue 2: 0 waiting, 0 being served.
#   Queue 3: 0 waiting, 0 being served.
#   Additional Screening: 3 needed it so far.
